# %%
from IPython.display import Image
Image(filename="E:\The-linear-regression-model.png")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=[1.2,2.5,3.2,4.5,5.2,6.5,7.2,8.3,9.6,4.5,6.2,7.9,8.6,6.8,4.1,7.8,8.9,5.4]
y=[125,250,330,465,562,654,789,859,958,452,635,741,852,654,412,753,851,589]
# Out:
# 18

# %%
X=np.array(x)
Y=np.array(y)

# %%
from IPython.display import Image
Image(filename="E:\linear_regression-2.png")

# %%
m=10
c=5
lr= 0.02
for i in range(200):
    yhat=X*m+c
    E=np.mean(np.square(Y-yhat))
    m=m- lr*2*np.mean((yhat-Y)*X)
    c=c-lr*2*np.mean(yhat-Y)
    print(E)
# Out:
# 334412.05555555556
# 162659.87598797353
# 79331.09700516221
# 38902.571217353216
# 19287.899254507527
# 9771.454778034393
# 5154.352902727849
# 2914.258189884072
# 1827.4128122689856
# 1300.0879582693021
# 1044.2250796679741
# 920.067226452134
# 859.8087198540865
# 830.5523750001206
# 816.3375103696585
# 809.4205032206236
# 806.0443893163342
# 804.3864057628758
# 803.562203345285
# 803.1427216713329
# 802.9197921858289
# 802.7924161249606
# 802.7115901562233
# 802.6535375140099
# 802.6067205883072
# 802.5655398410249
# 802.527276718182
# 802.4906104468632
# 802.4548984315777
# 802.4198271250211
# 802.3852426413739
# 802.3510685750235
# 802.3172661286258
# 802.2838147683156
# 802.250702838061
# 802.2179230058663
# 802.1854700542555
# 802.1533398081109
# 802.1215286143379
# 802.090033089249
# 802.0588499958438
# 802.0279761841098
# 801.9974085619024
# 801.9671440806615
# 801.9371797283235
# 801.9075125257415
# 801.878139524782
# 801.8490578072683
# 801.8202644843045
# ...

# %%
print(m)
print(c)
# Out:
# 97.21058881359598
# 21.576686800416752

# %%
sns.scatterplot(X,Y)

# %%
def predict(a):
    ypred=a*m+c
    return ypred

# %%
yp=predict(X)

# %%
plt.scatter(X,Y)
plt.plot(X,yp,c='r')
plt.show()
